# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (0.9.2)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from librosa) (0.4.2)
# Requirement already satisfied: numba>=0.45.1 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from librosa) (0.53.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from librosa) (1.19.5)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from librosa) (1.5.4)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: packaging>=20.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from librosa) (21.3)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from librosa) (0.24.2)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from librosa) (4.4.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: setuptools in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from numba>=0.45.1->librosa) (58.0.4)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from numba>=0.45.1->librosa) (0.36.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from packaging>=20.0->librosa) (3.0.7)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from pooch>=1.0->librosa) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.9)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (1.19.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SoundFile
# Out:
# Requirement already satisfied: SoundFile in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (0.10.3.post1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: cffi>=1.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from SoundFile) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from cffi>=1.0->SoundFile) (2.21)

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from sklearn) (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from scikit-learn->sklearn) (1.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pipwin
# Out:
# Requirement already satisfied: pipwin in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (0.5.2)
# Requirement already satisfied: js2py in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from pipwin) (0.71)
# Requirement already satisfied: requests in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from pipwin) (2.27.1)
# Requirement already satisfied: docopt in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from pipwin) (0.6.2)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from pipwin) (4.11.1)
# Requirement already satisfied: pyprind in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from pipwin) (2.11.3)
# Requirement already satisfied: packaging in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from pipwin) (21.3)
# Requirement already satisfied: six in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from pipwin) (1.16.0)
# Requirement already satisfied: pySmartDL>=1.3.1 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from pipwin) (1.3.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from beautifulsoup4>=4.9.0->pipwin) (2.3.2.post1)
# Requirement already satisfied: pyjsparser>=2.5.1 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from js2py->pipwin) (2.7.1)
# Requirement already satisfied: tzlocal>=1.2 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from js2py->pipwin) (4.2)
# Requirement already satisfied: tzdata in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from tzlocal>=1.2->js2py->pipwin) (2022.2)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from tzlocal>=1.2->js2py->pipwin) (0.1.0.post0)
# Requirement already satisfied: backports.zoneinfo in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from tzlocal>=1.2->js2py->pipwin) (0.2.1)
# Requirement already satisfied: importlib-resources in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from backports.zoneinfo->tzlocal>=1.2->js2py->pipwin) (5.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from importlib-resources->backports.zoneinfo->tzlocal>=1.2->js2py->pipwin) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from packaging->pipwin) (3.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from requests->pipwin) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from requests->pipwin) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from requests->pipwin) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (from requests->pipwin) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyaudio==0.2.11
# Out:
# Requirement already satisfied: pyaudio==0.2.11 in c:\users\aravi\anaconda3\envs\pyt36\lib\site-packages (0.2.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
import soundfile # to read audio file
import numpy as np
import librosa # to extract speech features
import glob
import os
import pickle # to save model after training
from sklearn.model_selection import train_test_split # for splitting training and testing
from sklearn.neural_network import MLPClassifier # multi-layer perceptron model
from sklearn.metrics import accuracy_score # to measure how good we are

# %%
def extract_feature(file_name, **kwargs):
    """
    Extract feature from audio file `file_name`
        Features supported:
            - MFCC (mfcc)
            - Chroma (chroma)
            - MEL Spectrogram Frequency (mel)
            - Contrast (contrast)
            - Tonnetz (tonnetz)
        e.g:
        `features = extract_feature(path, mel=True, mfcc=True)`
    """
    mfcc = kwargs.get("mfcc")
    chroma = kwargs.get("chroma")
    mel = kwargs.get("mel")
    contrast = kwargs.get("contrast")
    tonnetz = kwargs.get("tonnetz")
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate = sound_file.samplerate
        if chroma or contrast:
            stft = np.abs(librosa.stft(X))
        result = np.array([])
        if mfcc:
            mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
            result = np.hstack((result, mfccs))
        if chroma:
            chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result = np.hstack((result, chroma))
        if mel:
            mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
            result = np.hstack((result, mel))
        if contrast:
            contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
            result = np.hstack((result, contrast))
        if tonnetz:
            tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T,axis=0)
            result = np.hstack((result, tonnetz))
    return result

# %%
# all emotions on RAVDESS dataset
int2emotion = {
    "01": "neutral",
    "02": "calm",
    "03": "happy",
    "04": "sad",
    "05": "angry",
    "06": "fearful",
    "07": "disgust",
    "08": "surprised"
}

AVAILABLE_EMOTIONS = {
    "angry",
    "sad",
    "neutral",
    "happy"
}

def load_data(test_size=0.02):
    X, y = [], []
    for file in glob.glob("data/Actor_*/*.wav"):
        # get the base name of the audio file
        basename = os.path.basename(file)
        # get the emotion label
        emotion = int2emotion[basename.split("-")[2]]
        # we allow only AVAILABLE_EMOTIONS we set
        if emotion not in AVAILABLE_EMOTIONS:
            continue
        # extract speech features
        features = extract_feature(file, mfcc=True, chroma=True, mel=True)
        # add to data
        X.append(features)
        y.append(emotion)
    # split the data to training and testing and return it
    return train_test_split(np.array(X), y, test_size=test_size, random_state=7)

# %%
# load RAVDESS dataset, 75% training 25% testing
X_train, X_test, y_train, y_test = load_data(test_size=0.25)
# Out:
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 3.0517578e-05  3.0517578e-05  3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[3.0517578e-05 3.0517578e-05 0.0000000e+00 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 3.0517578e-05 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 3.0517578e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00 -3.0517578e-05 -3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-0.00061035 -0.00048828 -0.00039673 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.00231934  0.00213623 -0.00231934 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 7.3242188e-04  1.0986328e-03 -6.7138672e-04 ...  9.1552734e-05
#   3.6621094e-04  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.00033569 0.00024414 0.00024414 ... 0.00036621 0.00033569 0.00045776] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00 0.0000000e+00
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#   0.0000000e+00 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -3.0517578e-05
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -3.0517578e-05
#  -3.0517578e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00 3.0517578e-05
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 3.0517578e-05 3.0517578e-05
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-3.0517578e-05  0.0000000e+00  0.0000000e+00 ...  6.1035156e-05
#   3.0517578e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-3.0517578e-05 -3.0517578e-05 -3.0517578e-05 ... -3.0517578e-05
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[6.1035156e-05 3.0517578e-05 0.0000000e+00 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 6.1035156e-05  6.1035156e-05  9.1552734e-05 ... -3.0517578e-05
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 5.1879883e-04 -6.1035156e-05 -4.2724609e-04 ...  0.0000000e+00
#  -9.1552734e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 1.2207031e-04  1.5258789e-04 -3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-0.00027466 -0.00024414 -0.00027466 ... -0.00015259 -0.00021362
#  -0.00024414] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-9.1552734e-05 -9.1552734e-04 -1.0986328e-03 ...  2.7465820e-04
#   3.0517578e-04  3.6621094e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#  -1.5258789e-04 -1.5258789e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 6.1035156e-05 6.1035156e-05
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00042725 -0.00039673
#  -0.00033569] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-3.0517578e-05  0.0000000e+00 -3.0517578e-05 ...  2.7465820e-04
#   3.0517578e-04  2.7465820e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  3.0517578e-05  3.0517578e-05 ...  0.0000000e+00
#  -3.0517578e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-6.7138672e-04 -7.0190430e-04 -6.1035156e-04 ...  6.1035156e-05
#   6.1035156e-05  6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  3.0517578e-05 ... -3.6926270e-03
#  -7.4768066e-03 -8.6975098e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0
as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 3.0517578e-05  3.0517578e-05  0.0000000e+00 ... -3.0517578e-05
#  -3.0517578e-05 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00152588 -0.00149536
#  -0.00149536] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.         0.         0.         ... 0.00283813 0.0027771  0.0027771 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#  -6.1035156e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00021362 -0.00027466
#  -0.00024414] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-3.0517578e-05 -3.0517578e-05  0.0000000e+00 ... -6.1035156e-05
#  -3.0517578e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 6.1035156e-05  3.0517578e-05  3.0517578e-05 ... -6.1035156e-05
#  -9.1552734e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[3.0517578e-05 6.1035156e-05 6.1035156e-05 ... 3.0517578e-05 3.0517578e-05
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-3.0517578e-05  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#  -6.1035156e-05 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 3.0517578e-05 0.0000000e+00
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-3.0517578e-05  0.0000000e+00 -3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-3.0517578e-05  0.0000000e+00  0.0000000e+00 ... -7.9345703e-04
#  -8.2397461e-04 -8.2397461e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.         0.         0.         ... 0.00012207 0.00012207 0.00015259] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[3.0517578e-05 0.0000000e+00 3.0517578e-05 ... 0.0000000e+00 3.0517578e-05
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[3.0517578e-05 3.0517578e-05 3.0517578e-05 ... 1.2207031e-04 1.2207031e-04
#  1.2207031e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00210571 -0.00216675
#  -0.0020752 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-3.0517578e-05 -3.0517578e-05 -3.0517578e-05 ... -6.1035156e-05
#  -6.1035156e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#  -3.0517578e-05 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-3.0517578e-05 -6.1035156e-05 -3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 9.1552734e-05 1.2207031e-04
#  1.2207031e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-3.0517578e-05  0.0000000e+00 -3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[6.1035156e-05 0.0000000e+00 3.0517578e-05 ... 1.5258789e-04 1.5258789e-04
#  1.8310547e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-1.5258789e-04 -1.5258789e-04 -1.5258789e-04 ...  9.1552734e-05
#   9.1552734e-05  9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-3.0517578e-05  0.0000000e+00 -3.0517578e-05 ...  1.5258789e-04
#   1.5258789e-04  1.8310547e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-6.1035156e-05 -6.1035156e-05 -3.0517578e-05 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.         0.         0.         ... 0.00042725 0.00042725 0.00042725] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-9.1552734e-05 -1.2207031e-04 -1.2207031e-04 ...  0.0000000e+00
#   0.0000000e+00 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  1.3732910e-03
#   1.4038086e-03  1.4343262e-03] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 9.1552734e-05  3.0517578e-05  1.2207031e-04 ... -3.0517578e-05
#   0.0000000e+00 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -1.2207031e-04
#  -1.5258789e-04 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00 -3.0517578e-05 ...  0.0000000e+00
#  -3.0517578e-05 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00 -3.0517578e-05  0.0000000e+00 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 3.0517578e-05  3.0517578e-05  0.0000000e+00 ... -6.1035156e-05
#  -6.1035156e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00012207 -0.00012207
#  -0.00012207] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-6.1035156e-05 -6.1035156e-05 -6.1035156e-05 ...  1.2207031e-04
#   1.5258789e-04  9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 3.0517578e-05 6.1035156e-05
#  3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#  -6.1035156e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00 -6.1035156e-05 -1.5258789e-04 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  0.0000000e+00
#  -6.1035156e-05 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ... -6.1035156e-05
#  -3.0517578e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 3.0517578e-04  3.3569336e-04  3.0517578e-04 ... -9.1552734e-05
#  -9.1552734e-05 -1.2207031e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[9.1552734e-05 9.1552734e-05 6.1035156e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 3.0517578e-05  3.0517578e-05  3.0517578e-05 ... -9.1552734e-05
#  -6.1035156e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-6.1035156e-05 -3.0517578e-05  0.0000000e+00 ...  0.0000000e+00
#   0.0000000e+00  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 6.1035156e-05  6.1035156e-05  6.1035156e-05 ... -9.1552734e-05
#  -9.1552734e-05 -6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-2.1362305e-04 -9.1552734e-05  0.0000000e+00 ... -1.2207031e-04
#  -1.5258789e-04 -1.2207031e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[6.1035156e-05 6.1035156e-05 9.1552734e-05 ... 0.0000000e+00 0.0000000e+00
#  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[1.8310547e-04 1.5258789e-04 3.0517578e-05 ... 9.1552734e-05 9.1552734e-05
#  9.1552734e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 1.2207031e-04  1.2207031e-04  1.5258789e-04 ... -2.4414062e-04
#  -9.1552734e-05  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-3.3569336e-04 -9.1552734e-05  3.9672852e-04 ...  1.5258789e-04
#   1.2207031e-04  1.2207031e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[ 1.8310547e-04  1.8310547e-04  6.1035156e-05 ... -3.0517578e-05
#   0.0000000e+00 -3.0517578e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[3.0517578e-05 3.0517578e-05 3.0517578e-05 ... 1.2207031e-04 1.5258789e-04
#  1.2207031e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# C:\Users\aravi\anaconda3\envs\pyt36\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: Pass y=[-0.00012207 -0.00015259 -0.00018311 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error

# %%
# print some details
# number of samples in training data
print("[+] Number of training samples:", X_train.shape[0])
# number of samples in testing data
print("[+] Number of testing samples:", X_test.shape[0])
# number of features used
# this is a vector of features extracted 
# using extract_features() function
print("[+] Number of features:", X_train.shape[1])

# %%
# best model, determined by a grid search
model_params = {
    'alpha': 0.01,
    'batch_size': 256,
    'epsilon': 1e-08, 
    'hidden_layer_sizes': (300,), 
    'learning_rate': 'adaptive', 
    'max_iter': 500, 
}

# %%
# initialize Multi Layer Perceptron classifier
# with best parameters ( so far )
model = MLPClassifier(**model_params)

# %%
# train the model
print("[*] Training the model...")
model.fit(X_train, y_train)

# %%
# predict 25% of data to measure how good we are
y_pred = model.predict(X_test)

# calculate the accuracy
accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)

print("Accuracy: {:.2f}%".format(accuracy*100))

# %%
# now we save the model
# make result directory if doesn't exist yet
if not os.path.isdir("result"):
    os.mkdir("result")

pickle.dump(model, open("result/mlp_classifier.model", "wb"))

# %%
pip install utils

# %%
import pyaudio
import os
import wave
import pickle
from sys import byteorder
from array import array
from struct import pack
from sklearn.neural_network import MLPClassifier

#from utils import extract_feature

THRESHOLD = 500
CHUNK_SIZE = 1024
FORMAT = pyaudio.paInt16
RATE = 16000

SILENCE = 30

def is_silent(snd_data):
    "Returns 'True' if below the 'silent' threshold"
    return max(snd_data) < THRESHOLD

def normalize(snd_data):
    "Average the volume out"
    MAXIMUM = 16384
    times = float(MAXIMUM)/max(abs(i) for i in snd_data)

    r = array('h')
    for i in snd_data:
        r.append(int(i*times))
    return r

def trim(snd_data):
    "Trim the blank spots at the start and end"
    def _trim(snd_data):
        snd_started = False
        r = array('h')

        for i in snd_data:
            if not snd_started and abs(i)>THRESHOLD:
                snd_started = True
                r.append(i)

            elif snd_started:
                r.append(i)
        return r

    # Trim to the left
    snd_data = _trim(snd_data)

    # Trim to the right
    snd_data.reverse()
    snd_data = _trim(snd_data)
    snd_data.reverse()
    return snd_data

def add_silence(snd_data, seconds):
    "Add silence to the start and end of 'snd_data' of length 'seconds' (float)"
    r = array('h', [0 for i in range(int(seconds*RATE))])
    r.extend(snd_data)
    r.extend([0 for i in range(int(seconds*RATE))])
    return r

def record():
    """
    Record a word or words from the microphone and 
    return the data as an array of signed shorts.
    Normalizes the audio, trims silence from the 
    start and end, and pads with 0.5 seconds of 
    blank sound to make sure VLC et al can play 
    it without getting chopped off.
    """
    p = pyaudio.PyAudio()
    stream = p.open(format=FORMAT, channels=1, rate=RATE,
        input=True, output=True,
        frames_per_buffer=CHUNK_SIZE)

    num_silent = 0
    snd_started = False

    r = array('h')

    while 1:
        # little endian, signed short
        snd_data = array('h', stream.read(CHUNK_SIZE))
        if byteorder == 'big':
            snd_data.byteswap()
        r.extend(snd_data)

        silent = is_silent(snd_data)

        if silent and snd_started:
            num_silent += 1
        elif not silent and not snd_started:
            snd_started = True

        if snd_started and num_silent > SILENCE:
            break

    sample_width = p.get_sample_size(FORMAT)
    stream.stop_stream()
    stream.close()
    p.terminate()

    r = normalize(r)
    r = trim(r)
    r = add_silence(r, 0.5)
    return sample_width, r

def record_to_file(path):
    "Records from the microphone and outputs the resulting data to 'path'"
    sample_width, data = record()
    data = pack('<' + ('h'*len(data)), *data)

    wf = wave.open(path, 'wb')
    wf.setnchannels(1)
    wf.setsampwidth(sample_width)
    wf.setframerate(RATE)
    wf.writeframes(data)
    wf.close()



if __name__ == "__main__":
    # load the saved model (after training)
    model = pickle.load(open("result/mlp_classifier.model", "rb"))
    print("Please talk")
    filename = "test.wav"
    # record the file (start talking)
    record_to_file(filename)
    # extract features and reshape it
    features = extract_feature(filename, mfcc=True, chroma=True, mel=True).reshape(1, -1)
    # predict
    result = model.predict(features)[0]
    # show the result !
    print("result:", result)
